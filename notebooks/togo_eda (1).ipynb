# %%
import sys
sys.path.append("..")
from src.data_utils import *

df = load_data("../data/togo_raw.csv")
df = drop_high_missing(df)

df = clean_outliers(df, zscore_columns=["GHI", "ModA", "ModB"], clip_columns=["DHI", "WS", "WSgust"])
df = clean_limit(df)
df = finalize_clean(df)
save_clean(df, "../data/togo_clean(2).csv")

df.head()
# Out:
#                  GHI           DNI            DHI           ModA  \
# count  525259.000000  525259.00000  525259.000000  525259.000000
# mean      231.063429     150.86896     115.757744     225.529849
# std       320.763772     250.56202     154.893862     316.528883
# min         0.000000       0.00000       0.000000       0.000000
# 25%         0.000000       0.00000       0.000000       0.000000
# 50%         2.000000       0.00000       2.500000       4.300000
# 75%       441.300000     245.30000     215.300000     421.300000
# max      1198.000000    1004.50000     561.242000    1171.200000
#
#                 ModB           Tamb             RH             WS  \
# count  525259.000000  525259.000000  525259.000000  525259.000000
# mean      218.959810      27.750696      55.003371       2.357263
# std       307.100794       4.759070      28.784553       1.425614
# min         0.000000      14.900000       3.300000       0.000000
# ...

# %%
import sys
sys.path.append("..")

import pandas as pd
from src.plot_utils import *

df = pd.read_csv("../data/togo_clean(2).csv", parse_dates=['Timestamp'])
df = df.set_index('Timestamp')
df = df.sort_index()

df.head()

plot_time_series(df, ['GHI', 'DNI', 'DHI', 'Tamb'])
plot_monthly_average(df, ['GHI', 'DNI', 'DHI', 'Tamb'])
plot_daily_pattern(df, "GHI")
plot_daily_pattern(df, "WS")
# Out:
# Matplotlib is building the font cache; this may take a moment.
